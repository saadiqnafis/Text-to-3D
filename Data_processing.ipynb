# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import glob

path = os.getcwd()
print("Current working directory: ", path)

data_path = os.path.join(path, "AI_model/ShapeNetSem")
print("Data directory: ", data_path)
# Out:
# Current working directory:  /content
# Data directory:  /content/AI_model/ShapeNetSem

# %%
# mount files from the screenshots folder
# create batches of screenshots
# fine-tune the diffusion model

folder_names = os.listdir('/content/drive/MyDrive/AI_model/ShapeNetSem')

# %%
print(folder_names)
# Out:
# ['metadata.csv', 'categories.synset.csv', 'materials.csv', 'taxonomy.txt', 'models-OBJ.zip', 'models-screenshots.zip', 'models', 'screenshots']

# %%
from zipfile import ZipFile

# %%
with ZipFile("/content/drive/MyDrive/AI_model/ShapeNetSem/models-OBJ.zip", "r") as f:
  f.extractall("/content/drive/MyDrive/AI_model/ShapeNetSem")

# %%
# The screenshots have been all
# with ZipFile("/content/drive/MyDrive/AI_model/ShapeNetSem/models-screenshots.zip", "r") as f:
#   f.extractall("/content/drive/MyDrive/AI_model/ShapeNetSem")
