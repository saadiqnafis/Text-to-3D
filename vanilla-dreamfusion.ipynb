# %% [markdown]
# # Example usage of [stable-dreamfusion](https://github.com/ashawkey/stable-dreamfusion)
# Pure-pytorch version

# %% [markdown]
# ### Check the machine

# %%
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# ### Setup

# %%
#@title install dependencies
! git clone https://github.com/ashawkey/stable-dreamfusion.git

# %cd stable-dreamfusion

# install requirements
! pip install -r requirements.txt
! pip install git+https://github.com/NVlabs/nvdiffrast/
! pip install -U diffusers


# install specific version of transformers
# !pip install transformers==4.31.0
# Out:
# Cloning into 'stable-dreamfusion'...
# remote: Enumerating objects: 1281, done.
# remote: Counting objects: 100% (663/663), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 1281 (delta 530), reused 574 (delta 501), pack-reused 618
# Receiving objects: 100% (1281/1281), 17.12 MiB | 20.47 MiB/s, done.
# Resolving deltas: 100% (783/783), done.
# /content/stable-dreamfusion
# Collecting git+https://github.com/NVlabs/nvdiffrast/ (from -r requirements.txt (line 36))
#   Cloning https://github.com/NVlabs/nvdiffrast/ to /tmp/pip-req-build-vqscjr2f
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast/ /tmp/pip-req-build-vqscjr2f
#   Resolved https://github.com/NVlabs/nvdiffrast/ to commit c5caf7bdb8a2448acc491a9faa47753972edd380
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/openai/CLIP.git (from -r requirements.txt (line 44))
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-vhbvb7sj
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-vhbvb7sj
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (13.4.2)
# Collecting ninja (from -r requirements.txt (line 3))
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (4.7.0.72)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (0.4.8)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (2.0.1+cu118)
# Collecting torch-ema (from -r requirements.txt (line 14))
#   Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Collecting einops (from -r requirements.txt (line 15))
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (2.12.3)
# Collecting tensorboardX (from -r requirements.txt (line 17))
#   Downloading tensorboardX-2.6.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 13.7 MB/s eta 0:00:00
# Collecting dearpygui (from -r requirements.txt (line 20))
#   Downloading dearpygui-1.9.1-cp310-cp310-manylinux1_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 50.9 MB/s eta 0:00:00
# Collecting huggingface_hub (from -r requirements.txt (line 26))
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.3 MB/s eta 0:00:00
# Collecting diffusers>=0.9.0 (from -r requirements.txt (line 27))
#   Downloading diffusers-0.19.3-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.6 MB/s eta 0:00:00
# Collecting accelerate (from -r requirements.txt (line 28))
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 18.1 MB/s eta 0:00:00
# Collecting transformers (from -r requirements.txt (line 29))
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 98.8 MB/s eta 0:00:00
# Collecting xatlas (from -r requirements.txt (line 32))
#   Downloading xatlas-0.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.4/229.4 kB 27.7 MB/s eta 0:00:00
# Collecting trimesh (from -r requirements.txt (line 33))
#   Downloading trimesh-3.23.0-py3-none-any.whl (686 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.3/686.3 kB 72.5 MB/s eta 0:00:00
# Collecting PyMCubes (from -r requirements.txt (line 34))
#   Downloading PyMCubes-0.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.3/274.3 kB 34.3 MB/s eta 0:00:00
# Collecting pymeshlab (from -r requirements.txt (line 35))
#   Downloading pymeshlab-2022.2.post4-cp310-cp310-manylinux_2_31_x86_64.whl (64.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 MB 11.8 MB/s eta 0:00:00
# Collecting carvekit-colab (from -r requirements.txt (line 39))
#   Downloading carvekit_colab-4.1.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 9.4 MB/s eta 0:00:00
# Collecting omegaconf (from -r requirements.txt (line 40))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.0 MB/s eta 0:00:00
# Collecting pytorch-lightning (from -r requirements.txt (line 41))
#   Downloading pytorch_lightning-2.0.6-py3-none-any.whl (722 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.8/722.8 kB 50.3 MB/s eta 0:00:00
# Collecting taming-transformers-rom1504 (from -r requirements.txt (line 42))
#   Downloading taming_transformers_rom1504-0.0.6-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 5.8 MB/s eta 0:00:00
# Collecting kornia (from -r requirements.txt (line 43))
#   Downloading kornia-0.7.0-py2.py3-none-any.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 47)) (4.6.6)
# Collecting timm (from -r requirements.txt (line 50))
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 75.0 MB/s eta 0:00:00
# Collecting debugpy-run (from -r requirements.txt (line 53))
#   Downloading debugpy_run-1.6-py3-none-any.whl (10 kB)
# Collecting sentencepiece (from -r requirements.txt (line 56))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.0 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 13)) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 13)) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 13)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 13)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 13)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 13)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 13)) (16.0.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->-r requirements.txt (line 16)) (0.41.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 26)) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 26)) (6.0.1)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from diffusers>=0.9.0->-r requirements.txt (line 27)) (4.6.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers>=0.9.0->-r requirements.txt (line 27)) (2022.10.31)
# Collecting safetensors>=0.3.1 (from diffusers>=0.9.0->-r requirements.txt (line 27))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 28)) (5.9.5)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 29))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.2 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from carvekit-colab->-r requirements.txt (line 39)) (0.15.2+cu118)
# Collecting loguru (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.8 MB/s eta 0:00:00
# Collecting uvicorn (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.4 MB/s eta 0:00:00
# Collecting fastapi (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading fastapi-0.100.1-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 8.4 MB/s eta 0:00:00
# Collecting starlette (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading starlette-0.31.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from carvekit-colab->-r requirements.txt (line 39)) (1.10.12)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from carvekit-colab->-r requirements.txt (line 39)) (8.1.6)
# Collecting aiofiles (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting python-multipart (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.6 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->-r requirements.txt (line 40))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning->-r requirements.txt (line 41))
#   Downloading torchmetrics-1.0.2-py3-none-any.whl (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 65.5 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning->-r requirements.txt (line 41))
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Collecting ftfy (from clip==1.0->-r requirements.txt (line 44))
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown->-r requirements.txt (line 47)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->-r requirements.txt (line 47)) (4.11.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->huggingface_hub->-r requirements.txt (line 26)) (3.8.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 16)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 16)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 16)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 16)) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 16)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 16)) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 16)) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->-r requirements.txt (line 47)) (2.4.1)
# Collecting starlette (from carvekit-colab->-r requirements.txt (line 39))
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->carvekit-colab->-r requirements.txt (line 39)) (3.7.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0->-r requirements.txt (line 44)) (0.2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 16)) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 13)) (1.3.0)
# Collecting h11>=0.8 (from uvicorn->carvekit-colab->-r requirements.txt (line 39))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->-r requirements.txt (line 26)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->-r requirements.txt (line 26)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->-r requirements.txt (line 26)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->-r requirements.txt (line 26)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->-r requirements.txt (line 26)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->huggingface_hub->-r requirements.txt (line 26)) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->carvekit-colab->-r requirements.txt (line 39)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->carvekit-colab->-r requirements.txt (line 39)) (1.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 16)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 16)) (3.2.2)
# Building wheels for collected packages: nvdiffrast, antlr4-python3-runtime, clip
#   Building wheel for nvdiffrast (setup.py) ... done
#   Created wheel for nvdiffrast: filename=nvdiffrast-0.3.1-py3-none-any.whl size=137848 sha256=a8af9ae450b7a522f52eb40f1b242da15faa3928d068173cca13212cb1cc4380
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zb7agse6/wheels/4f/a3/e6/b3dbfa8dd5aebc3efe7b2ecb646ad1037fb3ab27ef7d6e6d02
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144552 sha256=5da8d28d96905d3f4a3823a936769b3a039ff459d37d4ca1fd3257007bc258c9
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369498 sha256=1ee791c60837ffcf002966f1a10b8221f63205b8aed9faf4488e407e1b4b615f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zb7agse6/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built nvdiffrast antlr4-python3-runtime clip
# Installing collected packages: xatlas, tokenizers, sentencepiece, safetensors, ninja, antlr4-python3-runtime, trimesh, tensorboardX, python-multipart, pymeshlab, omegaconf, nvdiffrast, loguru, lightning-utilities, h11, ftfy, einops, debugpy-run, dearpygui, aiofiles, uvicorn, starlette, PyMCubes, huggingface_hub, transformers, fastapi, diffusers, torchmetrics, pytorch-lightning, torch-ema, timm, taming-transformers-rom1504, kornia, clip, carvekit-colab, accelerate
# Successfully installed PyMCubes-0.1.4 accelerate-0.21.0 aiofiles-23.1.0 antlr4-python3-runtime-4.9.3 carvekit-colab-4.1.0 clip-1.0 dearpygui-1.9.1 debugpy-run-1.6 diffusers-0.19.3 einops-0.6.1 fastapi-0.100.1 ftfy-6.1.1 h11-0.14.0 huggingface_hub-0.16.4 kornia-0.7.0 lightning-utilities-0.9.0 loguru-0.7.0 ninja-1.11.1 nvdiffrast-0.3.1 omegaconf-2.3.0 pymeshlab-2022.2.post4 python-multipart-0.0.6 pytorch-lightning-2.0.6 safetensors-0.3.1 sentencepiece-0.1.99 starlette-0.27.0 taming-transformers-rom1504-0.0.6 tensorboardX-2.6.2 timm-0.9.2 tokenizers-0.13.3 torch-ema-0.3 torchmetrics-1.0.2 transformers-4.31.0 trimesh-3.23.0 uvicorn-0.23.2 xatlas-0.0.7
# Collecting git+https://github.com/NVlabs/nvdiffrast/
#   Cloning https://github.com/NVlabs/nvdiffrast/ to /tmp/pip-req-build-uz891jko
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast/ /tmp/pip-req-build-uz891jko
#   Resolved https://github.com/NVlabs/nvdiffrast/ to commit c5caf7bdb8a2448acc491a9faa47753972edd380
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nvdiffrast==0.3.1) (1.22.4)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from diffusers) (4.6.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.12.2)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.16.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.27.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.3.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (9.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: transformers==4.31.0 in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0) (3.4)

# %% [markdown]
# ### Training & Testing
# * It takes about 0.7s per training step, so the default 5000 training steps take around 1 hour to finish. A larger `Training_iters` usually leads to better results.
# * If CUDA OOM, try to decrease `Num_steps`, `Upsample_steps`, and `Training_nerf_resolution`.
# * If the NeRF fails to learn anything (empty scene, only background), try to decrease `Lambda_entropy` which regularizes the learned opacity.

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#@markdown ####**Training Settings:**
Prompt_text = "a hot air balloon" #@param {type: 'string'}
Training_iters = 3000 #@param {type: 'integer'}
Learning_rate = 1e-3 #@param {type: 'number'}
Training_nerf_resolution = 64  #@param {type: 'integer'}
# CUDA_ray = True #@param {type: 'boolean'}
# View_dependent_prompt = True #@param {type: 'boolean'}
# FP16 = True #@param {type: 'boolean'}
Seed = 5 #@param {type: 'integer'}
Lambda_entropy = 1e-4 #@param {type: 'number'}
Num_steps = 64 #@param {type: 'number'}
Upsample_steps = 32 #@param {type: 'number'}
Checkpoint = 'latest' #@param {type: 'string'}

#@markdown ---

#@markdown ####**Output Settings:**
Workspace = "trial_1" #@param{type: 'string'}
Save_mesh = True #@param {type: 'boolean'}

# processings
Prompt_text = "'" + Prompt_text + "'"

# %%
#@title start training
import torch

# %run main.py -O2  --text {Prompt_text} --workspace {Workspace} --iters {Training_iters} --lr {Learning_rate} --w {Training_nerf_resolution} --h {Training_nerf_resolution} --seed {Seed} --lambda_entropy {Lambda_entropy} --ckpt {Checkpoint} --save_mesh --num_steps {Num_steps} --upsample_steps {Upsample_steps}
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Namespace(file=None, text='a hot air balloon', negative='', O=False, O2=True, test=False, six_views=False, eval_interval=1, test_interval=100, workspace='trial_1', seed='5', image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=True, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=3000, lr=0.001, ckpt='latest', cuda_ray=False, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='vanilla', optim='adan', sd_version='2.1', hf_key=None, fp16=True, vram_O=False, w=64, h=64, known_view_scale=1.5, known_view_noise_scale=0.002, dmtet_reso_scale=8, batch_size=1, bound=1, dt_gamma=0, min_near=0.01, radius_range=[3.0, 3.5], theta_range=[45, 105], phi_range=[-180, 180], fovy_range=[10, 30], default_radius=3.2, default_polar=90, default_azimuth=0, default_fovy=20, progressive_view=False, progressive_view_init_ratio=0.2, progressive_level=True, angle_overhead=30, angle_front=60, t_range=[0.02, 0.98], dont_override_stuff=False, lambda_entropy=0.0001, lambda_opacity=0, lambda_orient=0.01, lambda_tv=0, lambda_wd=0, lambda_mesh_normal=0.5, lambda_mesh_laplacian=0.5, lambda_guidance=1, lambda_rgb=1000, lambda_mask=500, lambda_normal=0, lambda_depth=10, lambda_2d_normal_smooth=0, lambda_3d_normal_smooth=0, save_guidance=False, save_guidance_interval=10, gui=False, W=800, H=800, radius=5, fovy=20, light_theta=60, light_phi=0, max_spp=1, zero123_config='./pretrained/zero123/sd-objaverse-finetune-c_concat-256.yaml', zero123_ckpt='pretrained/zero123/zero123-xl.ckpt', zero123_grad_scale='angle', dataset_size_train=100, dataset_size_valid=8, dataset_size_test=100, exp_start_iter=0, exp_end_iter=3000, images=None, ref_radii=[], ref_polars=[], ref_azimuths=[], zero123_ws=[], default_zero123_w=1)
# NeRFNetwork(
#   (encoder): FreqEncoder_torch()
#   (sigma_net): MLP(
#     (net): ModuleList(
#       (0): BasicBlock(
#         (dense): Linear(in_features=75, out_features=64, bias=True)
#         (activation): ReLU(inplace=True)
#       )
#       (1-3): 3 x ResBlock(
#         (dense): Linear(in_features=64, out_features=64, bias=True)
#         (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (activation): SiLU(inplace=True)
#       )
#       (4): Linear(in_features=64, out_features=4, bias=True)
#     )
#   )
#   (encoder_bg): FreqEncoder_torch()
#   (bg_net): MLP(
#     (net): ModuleList(
#       (0): BasicBlock(
#         (dense): Linear(in_features=27, out_features=32, bias=True)
#         (activation): ReLU(inplace=True)
#       )
#       (1): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# [INFO] loading stable diffusion...
# Downloading (…)ain/model_index.json:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)f06/unet/config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# Downloading (…)df06/vae/config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Pipelines loaded with `torch_dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `torch_dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `torch_dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# [INFO] loaded stable diffusion!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/stable-dreamfusion/main.py in <module>
#     394             guidance['clip'] = CLIP(device)
#     395
# --> 396         trainer = Trainer(' '.join(sys.argv), 'df', opt, model, guidance, device=device, workspace=opt.workspace, optimizer=optimizer, ema_decay=0.95, fp16=opt.fp16, lr_scheduler=scheduler, use_checkpoint=opt.ckpt, scheduler_update_every_step=True)
#     397
#     398         trainer.default_view_data = train_loader._data.get_default_view_data()
#
# /content/stable-dreamfusion/nerf/utils.py in __init__(self, argv, name, opt, model, guidance, criterion, optimizer, ema_decay, lr_scheduler, metrics, local_rank, world_size, device, mute, fp16, max_keep_ckpt, workspace, best_mode, use_loss_as_metric, report_metric_at_train, use_checkpoint, use_tensorboardX, scheduler_update_every_step)
#     261                     p.requires_grad = False
#     262                 self.embeddings[key] = {}
# --> 263             self.prepare_embeddings()
#     264
#     265         if isinstance(criterion, nn.Module):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /content/stable-dreamfusion/nerf/utils.py in prepare_embeddings(self)
#     357
#     358             if 'SD' in self.guidance:
# --> 359                 self.embeddings['SD']['default'] = self.guidance['SD'].get_text_embeds([self.opt.text])
#     360                 self.embeddings['SD']['uncond'] = self.guidance['SD'].get_text_embeds([self.opt.negative])
#     361
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /content/stable-dreamfusion/guidance/sd_utils.py in get_text_embeds(self, prompt)
#      79
#      80         inputs = self.tokenizer(prompt, padding='max_length', max_length=self.tokenizer.model_max_length, return_tensors='pt')
# ---> 81         embeddings = self.text_encoder(inputs.input_ids.to(self.device))[0]
#      82
#      83         return embeddings
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/modeling_clip.py in forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     821         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     822
# --> 823         return self.text_model(
#     824             input_ids=input_ids,
#     825             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/modeling_clip.py in forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     739             attention_mask = _expand_mask(attention_mask, hidden_states.dtype)
#     740
# --> 741         encoder_outputs = self.encoder(
#     742             inputs_embeds=hidden_states,
#     743             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/modeling_clip.py in forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     653                 )
#     654             else:
# --> 655                 layer_outputs = encoder_layer(
#     656                     hidden_states,
#     657                     attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/modeling_clip.py in forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     382         residual = hidden_states
#     383
# --> 384         hidden_states = self.layer_norm1(hidden_states)
#     385         hidden_states, attn_weights = self.self_attn(
#     386             hidden_states=hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     188
#     189     def forward(self, input: Tensor) -> Tensor:
# --> 190         return F.layer_norm(
#     191             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     192
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2513             layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2514         )
# -> 2515     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2516
#    2517
#
# RuntimeError: "LayerNormKernelImpl" not implemented for 'Half'

# %%
#@markdown ####**Testing Settings:**

Workspace_test = "trial_1" #@param{type: 'string'}
# Save_mesh = True #@param {type: 'boolean'}

# %%
#@title testing
import torch
torch.cuda.empty_cache()

# %run main.py -O2 --test --workspace {Workspace_test} --save_mesh --max_ray_batch 1024

# %% [markdown]
# ### Display results
# * RGB and Depth video are located at `{Workspace}/results/*.mp4`
# * Mesh is under `{Workspace}/mesh/`, you could see three files named `mesh.obj`, `mesh.mtl`, and `albedo.png`.

# %%
#@title display RGB video
import os
import glob
from IPython.display import HTML
from base64 import b64encode

def get_latest_file(path):
  dir_list = glob.glob(path)
  dir_list.sort(key=lambda x: os.path.getmtime(x))
  return dir_list[-1]

def show_video(video_path, video_width = 600):

  video_file = open(video_path, "r+b").read()
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"

  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

rgb_video = get_latest_file(os.path.join(Workspace, 'results', '*_rgb.mp4'))
show_video(rgb_video)
